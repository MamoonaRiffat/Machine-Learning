# %%
#Loading Bokeh and plotly libraries

# %%
from bokeh.plotting import figure, show, output_file
from bokeh.models import ColumnDataSource, FactorRange
import plotly as plt
import plotly.express as px
import seaborn as sns
import numpy as np
import pandas as pd
from bokeh.transform import dodge

# %%
df = pd.read_csv('GES.csv')
df.tail()
# Out:
#                                Country              Features  \
# 1605               Trinidad and Tobago  distribution losses
# 1606          Turks and Caicos Islands  distribution losses
# 1607               U.S. Virgin Islands  distribution losses
# 1608                           Uruguay  distribution losses
# 1609                         Venezuela  distribution losses
#
#                        Region     1980     1981     1982     1983     1984  \
# 1605  Central & South America    0.244     0.21    0.152    0.326     0.36
# 1606  Central & South America  0.00035  0.00035  0.00035  0.00035  0.00035
# 1607  Central & South America  0.05243  0.05537  0.05607  0.05761  0.05789
# 1608  Central & South America     0.55    0.426    0.627    0.662     0.78
# 1609  Central & South America    5.145    3.597    6.113    6.623    5.386
#
#          1985     1986  ...    2012    2013    2014    2015    2016  \
# 1605    0.407    0.337  ...   0.239   0.234   0.245   0.248   0.253
# 1606  0.00035  0.00035  ...       0       0       0       0       0
# 1607  0.05922  0.06055  ...   0.063    0.06    0.06    0.06   0.065
# 1608    0.702    0.911  ...   1.292   1.282   1.253    1.49   1.608
# 1609    6.818    8.605  ...  25.113  25.627  42.699  40.381  33.543
#
#            2017       2018       2019       2020         2021
# 1605   0.274864   0.425807   0.424101   0.422757     0.422757
# 1606      0.014     0.0125     0.0125     0.0125   0.01277172
# 1607      0.065       0.05      0.051      0.051        0.051
# 1608   1.694491   1.557257   1.322331   1.129273     1.129273
# 1609  32.237348  30.982821  25.637959  23.099784  23.04704156
#
# [5 rows x 45 columns]

# %%
africa_data = df[df['Region'] == 'Africa']
year = ['2013','2015','2017','2019'] 
data_year = df[['Region', year]]

p = figure(title=f'line Plot of Energy Generation by Region ({year})', x_axis_label='Region', y_axis_label='Energy Generation')
# Create a ColumnDataSource for the data
source = ColumnDataSource(data=data_year)

p.scatter(x='Region', y=year, source=source, line_width=2, line_color='blue', legend_label=year)
# Show the plot
show(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ABC\Desktop\Machine Learning\Task_day_9.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/ABC/Desktop/Machine%20Learning/Task_day_9.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> africa_data = df[df['Region'] == 'Africa']
#       <a href='vscode-notebook-cell:/c%3A/Users/ABC/Desktop/Machine%20Learning/Task_day_9.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> year = ['2013','2015','2017','2019']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ABC/Desktop/Machine%20Learning/Task_day_9.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> data_year = df[['Region', year]]
#       <a href='vscode-notebook-cell:/c%3A/Users/ABC/Desktop/Machine%20Learning/Task_day_9.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> p = figure(title=f'line Plot of Energy Generation by Region ({year})', x_axis_label='Region', y_axis_label='Energy Generation')
#       <a href='vscode-notebook-cell:/c%3A/Users/ABC/Desktop/Machine%20Learning/Task_day_9.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> # Create a ColumnDataSource for the data
#
# File c:\Users\ABC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\ABC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5871, in Index._get_indexer_strict(self, key, axis_name)
#    5868     keyarr = com.asarray_tuplesafe(keyarr)
#    5870 if self._index_as_unique:
# -> 5871     indexer = self.get_indexer_for(keyarr)
#    5872     keyarr = self.reindex(keyarr)[0]
#    5873 else:
#
# File c:\Users\ABC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5858, in Index.get_indexer_for(self, target)
#    5840 """
#    5841 Guaranteed return of an indexer even when non-unique.
#    5842
#    (...)
#    5855 array([0, 2])
#    5856 """
#    5857 if self._index_as_unique:
# -> 5858     return self.get_indexer(target)
#    5859 indexer, _ = self.get_indexer_non_unique(target)
#    5860 return indexer
#
# File c:\Users\ABC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3801, in Index.get_indexer(self, target, method, limit, tolerance)
#    3796     target = target.astype(dtype, copy=False)
#    3797     return this._get_indexer(
#    3798         target, method=method, limit=limit, tolerance=tolerance
#    3799     )
# -> 3801 return self._get_indexer(target, method, limit, tolerance)
#
# File c:\Users\ABC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3828, in Index._get_indexer(self, target, method, limit, tolerance)
#    3825     else:
#    3826         tgt_values = target._get_engine_target()
# -> 3828     indexer = self._engine.get_indexer(tgt_values)
#    3830 return ensure_platform_int(indexer)
#
# File c:\Users\ABC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:321, in pandas._libs.index.IndexEngine.get_indexer()
#
# File pandas\_libs\hashtable_class_helper.pxi:7131, in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'list'
